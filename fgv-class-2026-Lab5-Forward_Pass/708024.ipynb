# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split 
import matplotlib.pyplot as plt

# %% [markdown]
# # Lab 8 - Multi-layer Perceptron Forward Pass

# %% [markdown]
# ## Part I
# For this exercise you will implement a simple 2-layer perceptron (forward pass)
#
# For the first part you'll write a function that computes the forward pass of a 2-layer perecptron that predicts the prices of houses, using the usual Boston housing dataset.

# %%
housing_names = ["CRIM", "ZN", "INDUS", "CHAS", "NOX", "RM", "AGE", "DIS", "RAD", "TAX", "PTRATIO", "B", "LSTAT", "MEDV"]
boston = pd.read_table("housing.txt", names=housing_names, sep='\s+')

# %%
X = boston.values[:,:-1]
X = np.column_stack((np.ones(X.shape[0]), X))
y = boston.values[:,-1]

# %% [markdown]
# As usual, consider the MEDV as your target variable.
# * Split the data into training, validation and testing (70,15,15)% (you will need this for the next lab as we will build from this lab)

# %%
X_train, X_aux, y_train, y_aux = train_test_split(X, y, train_size= 0.7)
X_test, X_val, y_test, y_val = train_test_split(X_aux, y_aux, train_size= 0.5)

# %% [markdown]
# Now you will write the function that computes the forward pass.
# * I provide here a structure that you can follow for your function, but again, feel free to modify it as you see fit.
# * Use the sigmoid function as the activation of the hidden layer.
# * Don't forget about the biases!
# * *It is up to you to think what should be the activation for the output layer.*

# %%
def sigmoid_activation(z):
    return 1/(1+np.exp(-z))

# %%
def two_layer_perceptron(X, hidden_activation, output_activation, dim_input, dim_hidden, dim_output):
    """
    Implements the forward pass of a two-layer fully connected perceptron.
    
    Parameters
    ----------
    X : a 2-dimensional array
        The input data
    hidden_activation : function
        The activation function to be used for the hidden layer
    hidden_activation : function
        The activation function to be used for the output layer
    dim_input : int
        The dimensionality of the input layer
    dim_hidden : int
        The dimensionality of the hidden layer
    dim_output : int
        The dimensionality of the output layer
        
    Returns
    -------
    y_pred : float
        The output of the computation of the forward pass of the network
    """
    
    W1 = np.random.randn(dim_input, dim_hidden)
    a = hidden_activation(X@W1)
    z = np.column_stack((np.ones(X.shape[0]), a))

    W2 = np.random.randn(dim_hidden+1, dim_output)
    y_pred = output_activation(z@W2)
    
    
    return y_pred

# %%
def identity(x): return x

# %%
np.random.seed(0)
y_prev = two_layer_perceptron(X_train, sigmoid_activation, identity, 14, 30, 1)
y_prev
# Out:
# C:\Users\sodre\AppData\Local\Temp\ipykernel_22144\386652744.py:2: RuntimeWarning: overflow encountered in exp
#   return 1/(1+np.exp(-z))
# array([[-1.64738918],
#        [-1.32458402],
#        [-3.61042212],
#        [-2.82582257],
#        [-0.64237687],
#        [-1.32455252],
#        [-2.80818446],
#        [-1.32455259],
#        [-2.82779296],
#        [-1.32455252],
#        [-1.32455252],
#        [-2.55092106],
#        [-3.61042212],
#        [-2.90675127],
#        [-1.21416322],
#        [-2.55092106],
#        [-1.21416322],
#        [-1.3246143 ],
#        [-2.19351612],
#        [-3.61042212],
#        [-2.82779296],
#        [-3.33355021],
#        [-1.96869653],
#        [-2.25374683],
#        [-2.55092106],
#        [-1.96869646],
#        [-2.77003395],
#        [-1.32455252],
#        [-1.32455252],
#        [-1.32455252],
#        [-1.32455258],
#        [-2.82767815],
#        [-2.82778939],
#        [-1.96869862],
#        [-2.73717617],
#        [-1.32455252],
#        [-1.32455252],
#        [-2

#        [-1.32455252],
#        [-1.32455252],
#        [-2.82779296],
#        [-1.32455252],
#        [-3.61042158],
#        [-3.61042152],
#        [-1.32455252],
#        [-1.96869885],
#        [-2.22753043],
#        [-2.81580217],
#        [-1.59283842],
#        [-1.96869744],
#        [-3.57441588],
#        [-2.82779296],
#        [-2.73329085],
#        [-1.21416322],
#        [-1.32455252],
#        [-1.32455252],
#        [-3.33355022],
#        [-1.59454597],
#        [-1.32455252],
#        [-3.60676824],
#        [-1.96869646],
#        [-1.32455252],
#        [-2.19351007],
#        [-2.82779273],
#        [-3.61042212],
#        [-2.82779296],
#        [-2.7414689 ],
#        [-2.55092125],
#        [-1.50412913],
#        [-3.47701236],
#        [-2.11769621],
#        [-2.82774286],
#        [-3.61042212],
#        [-3.6103998 ],
#        [-1.32455252],
#        [-1.21416322],
#        [-1.32455252],
#        [-3.27730855],
#        [-3.54995119],
#        [-1.02515923],
#        [-2.82769543],
#        [-1.59454269],
#        [-2.82779297],
#        [-1.32455252],
#        [-2.82779293],
#        [-1.21417054],
#        [-2.55092105],
#        [-1.96869646],
#        [-2.82779292],
#        [-2.32336633],
#        [-1.32455252],
#        [-3.61042212],
#        [-1.32455252],
#        [-3.61042212],
#        [-2.06145678],
#        [-1.32459024],
#        [-1.32455252],
#        [-1.32455252],
#        [-2.55092679],
#        [-2.7626438 ],
#        [-0.70972211],
#        [-1.32455651],
#        [-2.24498127],
#        [-2.73911513],
#        [-1.96869646],
#        [-2.82779203],
#        [-1.32455252],
#        [-3.61035136],
#        [-3.61042212],
#        [-1.33023602],
#        [-1.96869646],
#        [-3.33359037],
#        [-2.82779587],
#        [-2.19357306],
#        [-1.32455252],
#        [-2.82774306],
#        [-1.54675659],
#        [-2.82779146],
#        [-2.19361724],
#        [-1.48070401],
#        [-2.19352511],
#        [-2.74145863],
#        [-3.61042212],
#        [-1.32455252],
#        [-1.32455252],
#        [-2.81012074],
#        [-1.96869646],
#        [-1.96869649],
#        [-3.61042212],
#        [-2.81029173],
#        [-3.59749926],
#        [-2.03881865],
#        [-1.21416814],
#        [-2.55092106],
#        [-2.63685185],
#        [-1.32455252],
#        [-2.19405604],
#        [-2.74145863],
#        [-2.55092106],
#        [-2.27345296],
#        [-1.32455252],
#        [-2.55445907],
#        [-2.5509213 ],
#        [-3.56919357],
#        [-2.19351601],
#        [-1.32455252],
#        [-1.3245526 ],
#        [-2.5509211 ],
#        [-1.01987578],
#        [-1.74897059],
#        [-3.55523622],
#        [-1.96869646],
#        [-3.61042212],
#        [-2.19355844],
#        [-1.32455252],
#        [-1.79824629],
#        [-1.32455252],
#        [-3.61042212],
#        [-2.06264969],
#        [-2.82779296],
#        [-1.32455252],
#        [-2.82759508],
#        [-3.33355021],
#        [-2.06264964],
#        [-2.82779192],
#        [-1.32501512],
#        [-2.82779296],
#        [-1.32455252],
#        [-2.55092115],
#        [-3.61042212],
#        [-1.32455252],
#        [-2.15367777],
#        [-1.99972228],
#        [-1.32455252],
#        [-2.81490407],
#        [-2.82779296],
#        [-3.61042212],
#        [-1.96869646],
#        [-2.55092107],
#        [-1.32455252],
#        [-1.32455252],
#        [-1.96869195],
#        [-2.55092129],
#        [-1.32455252],
#        [-1.39707916],
#        [-3.6104221 ],
#        [-1.32455252],
#        [-2.74007387],
#        [-2.82779296],
#        [-2.74145872],
#        [-3.33355021],
#        [-1.96869646],
#        [-1.32455252],
#        [-1.32455252],
#        [-2.82779296],
#        [-1.01987505],
#        [-1.32455252],
#        [-2.06264969],
#        [-1.32455252],
#        [-2.24557137],
#        [-2.17562895],
#        [-1.96869646],
#        [-3.60459413],
#        [-1.21416337],
#        [-1.21416322],
#        [-3.61042167],
#        [-3.61042212],
#        [-1.02472016],
#        [-1.32455255],
#        [-2.74145863],
#        [-1.32455252],
#        [-1.96869646],
#        [-3.61042212],
#        [-2.82484366],
#        [-1.36585507],
#        [-2.71401095],
#        [-2.79256146],
#        [-3.33349968],
#        [-1.99764446],
#        [-1.32455252],
#        [-2.82778466],
#        [-3.61042212],
#        [-0.74437032],
#        [-3.61042212],
#        [-2.82779294],
#        [-3.27282156],
#        [-2.55322505],
#        [-1.96869646],
#        [-1.32455252],
#        [-2.24557913],
#        [-2.55092106],
#        [-3.60947922],
#        [-2.82779289]])

# %% [markdown]
# Calculate the RMSE of the forward pass.

# %%
def rmse(t, y): return np.sqrt(np.mean(t**2 - y**2))

# %%
rmse(y_train, y_prev)
# Out:
# np.float64(24.348144103313782)

# %% [markdown]
# ## Part II
#
# For this exercise you will write a function that calculates the forward pass of a 2-layer perceptron that predicts the exact digit from a hand-written image, using the MNIST dataset.

# %%
from sklearn.datasets import load_digits

# %%
digits = load_digits()

# %%
X = digits.data
X = np.column_stack((np.ones(X.shape[0]), X))
y = digits.target

# %%
y
# Out:
# array([0, 1, 2, ..., 8, 9, 8], shape=(1797,))

# %%
X.shape
# Out:
# (1797, 65)

# %% [markdown]
# Again, you will split the data into training, validation and testing.

# %%
X_train, X_aux, y_train, y_aux = train_test_split(X, y, train_size= 0.7)
X_test, X_val, y_test, y_val = train_test_split(X_aux, y_aux, train_size= 0.5)

# %% [markdown]
# Write a function that calculates the forward pass for this multi-class classification problem.
# * You will use the sigmoid activation function for the hidden layer.
# * For the output layer you will have to write the softmax activation function (you can check the slides)
# * __Note:__ you can easily re-use the function that you coded for Part I if you do a simple modification and also include an input argument for the activation of the output layer.

# %%
def softmax_activation(z):
    M_exp = np.exp(z)
    M_exp_sum = np.sum(M_exp, axis= 1)
    
    return M_exp/M_exp_sum[:, np.newaxis]

# %%
y_prev_ = two_layer_perceptron(X_train, sigmoid_activation, softmax_activation, 65, 80, 10)

# %% [markdown]
# Lastly, calculate the error of this forward pass using the cross-entropy loss.

# %%
def CrossEntropy(target, predicted):
    pred = predicted[np.arange(predicted.shape[0]), target]
    result = - np.sum(np.log(pred))
    return result

# %%
CrossEntropy(y_train, y_prev_)
# Out:
# np.float64(16727.58546726666)
